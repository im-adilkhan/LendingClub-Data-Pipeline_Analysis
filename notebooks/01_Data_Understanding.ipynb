# %%
import pandas as pd
import numpy as np


pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows",100)

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\henry\OneDrive\Desktop\LendingClub-Data-Pipeline\data\raw\loan.csv",
    low_memory=False
)

# %%
print("Rows :",df.shape[0])
print("Columns :",df.shape[1])
# Out:
# Rows : 2260668
# Columns : 145

# %%
df.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       2500         2500           2500.0   36 months
# 1 NaN        NaN      30000        30000          30000.0   60 months
# 2 NaN        NaN       5000         5000           5000.0   36 months
# 3 NaN        NaN       4000         4000           4000.0   36 months
# 4 NaN        NaN      30000        30000          30000.0   60 months
#
#    int_rate  installment grade sub_grade       emp_title emp_length  \
# 0     13.56        84.92     C        C1            Chef  10+ years
# 1     18.94       777.23     D        D2     Postmaster   10+ years
# 2     17.97       180.69     D        D1  Administrative    6 years
# 3     18.94       146.51     D        D2   IT Supervisor  10+ years
# 4     16.14       731.78     C        C4        Mechanic  10+ years
#
#   home_ownership  annual_inc verification_status   issue_d loan_status  \
# 0           RENT     55000.0        Not Verified  Dec-2018     Current
# 1       MORTGAGE     90000.0     Source Verified  Dec-2018     Current
# 2       MORTGAGE     59280.0     Source Verified  Dec-2018     Current
# 3       MORTGAGE     92000.0     Source Verified  Dec-2018     Current
# 4       MORTGAGE     57250.0        Not Verified  Dec-2018     Current
#
#   pymnt_plan  url desc             purpose               title zip_code  \
# 0          n  NaN  NaN  debt_consolidation  Debt consolidation    109xx
# 1          n  NaN  NaN  debt_consolidation  Debt consolidation    713xx
# 2          n  NaN  NaN  debt_consolidation  Debt consolidation    490xx
# 3          n  NaN  NaN  debt_consolidation  Debt consolidation    985xx
# 4          n  NaN  NaN  debt_consolidation  Debt consolidation    212xx
#
#   addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 0         NY  18.24          0.0         Apr-2001             1.0
# 1         LA  26.52          0.0         Jun-1987             0.0
# 2         MI  10.51          0.0         Apr-2011             0.0
# 3         WA  16.74          0.0         Feb-2006             0.0
# 4         MD  26.35          0.0         Dec-2000             0.0
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                     NaN                    45.0       9.0      1.0
# 1                    71.0                    75.0      13.0      1.0
# 2                     NaN                     NaN       8.0      0.0
# 3                     NaN                     NaN      10.0      0.0
# 4                     NaN                     NaN      12.0      0.0
#
#    revol_bal  revol_util  total_acc initial_list_status  out_prncp  \
# 0       4341        10.3       34.0                   w    2386.02
# 1      12315        24.2       44.0                   w   29387.75
# 2       4599        19.1       13.0                   w    4787.21
# 3       5468        78.1       13.0                   w    3831.93
# 4        829         3.6       26.0                   w   29339.02
#
#    out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0        2386.02       167.02           167.02           113.98
# 1       29387.75      1507.11          1507.11           612.25
# 2        4787.21       353.89           353.89           212.79
# 3        3831.93       286.71           286.71           168.07
# 4       29339.02      1423.21          1423.21           660.98
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0          53.04                 0.0         0.0                      0.0
# 1         894.86                 0.0         0.0                      0.0
# 2         141.10                 0.0         0.0                      0.0
# 3         118.64                 0.0         0.0                      0.0
# 4         762.23                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     Feb-2019            84.92     Mar-2019           Feb-2019
# 1     Feb-2019           777.23     Mar-2019           Feb-2019
# 2     Feb-2019           180.69     Mar-2019           Feb-2019
# 3     Feb-2019           146.51     Mar-2019           Feb-2019
# 4     Feb-2019           731.78     Mar-2019           Feb-2019
#
#    collections_12_mths_ex_med  mths_since_last_major_derog  policy_code  \
# 0                         0.0                          NaN            1
# 1                         0.0                          NaN            1
# 2                         0.0                          NaN            1
# 3                         0.0                          NaN            1
# 4                         0.0                          NaN            1
#
#   application_type  annual_inc_joint  dti_joint verification_status_joint  \
# 0       Individual               NaN        NaN                       NaN
# 1       Individual               NaN        NaN                       NaN
# 2       Individual               NaN        NaN                       NaN
# 3       Individual               NaN        NaN                       NaN
# 4       Individual               NaN        NaN                       NaN
#
#    acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  \
# 0             0.0           0.0      16901.0          2.0          2.0
# 1             0.0        1208.0     321915.0          4.0          4.0
# 2             0.0           0.0     110299.0          0.0          1.0
# 3             0.0         686.0     305049.0          1.0          5.0
# 4             0.0           0.0     116007.0          3.0          5.0
#
#    open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# 0
NaN                 NaN                  NaN
#
#          sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 2260663                    NaN                               NaN
# 2260664                   17.0                               0.0
# 2260665                    NaN                               NaN
# 2260666                    NaN                               NaN
# 2260667                    NaN                               NaN
#
#          sec_app_collections_12_mths_ex_med  \
# 2260663                                 NaN
# 2260664                                 0.0
# 2260665                                 NaN
# 2260666                                 NaN
# 2260667                                 NaN
#
#          sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 2260663                                  NaN             N           NaN
# 2260664                                  7.0             N           NaN
# 2260665                                  NaN             N           NaN
# 2260666                                  NaN             N           NaN
# 2260667                                  NaN             N           NaN
#
#         hardship_reason hardship_status  deferral_term  hardship_amount  \
# 2260663             NaN             NaN            NaN              NaN
# 2260664             NaN             NaN            NaN              NaN
# 2260665             NaN             NaN            NaN              NaN
# 2260666             NaN             NaN            NaN              NaN
# 2260667             NaN             NaN            NaN              NaN
#
#         hardship_start_date hardship_end_date payment_plan_start_date  \
# 2260663                 NaN               NaN                     NaN
# 2260664                 NaN               NaN                     NaN
# 2260665                 NaN               NaN                     NaN
# 2260666                 NaN               NaN                     NaN
# 2260667                 NaN               NaN                     NaN
#
#          hardship_length  hardship_dpd hardship_loan_status  \
# 2260663              NaN           NaN                  NaN
# 2260664              NaN           NaN                  NaN
# 2260665              NaN           NaN                  NaN
# 2260666              NaN           NaN                  NaN
# 2260667              NaN           NaN                  NaN
#
#          orig_projected_additional_accrued_interest  \
# 2260663                                         NaN
# 2260664                                         NaN
# 2260665                                         NaN
# 2260666                                         NaN
# 2260667                                         NaN
#
#          hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 2260663                             NaN                           NaN
# 2260664                             NaN                           NaN
# 2260665                             NaN                           NaN
# 2260666                             NaN                           NaN
# 2260667                             NaN                           NaN
#
#         disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 2260663                Cash                    N                       NaN
# 2260664                Cash                    N                       NaN
# 2260665                Cash                    N                       NaN
# 2260666                Cash                    N                       NaN
# 2260667                Cash                    N                       NaN
#
#         settlement_status settlement_date  settlement_amount  \
# 2260663               NaN             NaN                NaN
# 2260664               NaN             NaN                NaN
# 2260665               NaN             NaN                NaN
# 2260666               NaN             NaN                NaN
# 2260667               NaN             NaN                NaN
#
#          settlement_percentage  settlement_term
# 2260663                    NaN              NaN
# 2260664                    NaN              NaN
# 2260665                    NaN              NaN
# 2260666                    NaN              NaN
# 2260667                    NaN              NaN

# %%
df.sample(5, random_state=42)
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 1758049 NaN        NaN      35000        35000          35000.0   36 months
# 686533  NaN        NaN      30000        30000          30000.0   60 months
# 900721  NaN        NaN      15000        15000          15000.0   36 months
# 1727912 NaN        NaN      24000        24000          24000.0   60 months
# 539691  NaN        NaN      14400        14400          14400.0   36 months
#
#          int_rate  installment grade sub_grade                emp_title  \
# 1758049     12.12      1164.51     B        B3  Legacy Physicians Group
# 686533      10.75       648.54     B        B4      Director of nursing
# 900721       7.49       466.53     A        A4                  Partner
# 1727912     21.15       651.31     E        E2    Einstein Bros. Bagels
# 539691       8.59       455.18     A        A5       Nurse practitioner
#
#         emp_length home_ownership  annual_inc verification_status   issue_d  \
# 1758049   < 1 year           RENT     90000.0            Verified  Jun-2013
# 686533     2 years           RENT    100000.0            Verified  Apr-2016
# 900721     5 years            OWN    100000.0     Source Verified  Oct-2016
# 1727912    5 years           RENT     58000.0     Source Verified  Sep-2013
# 539691     3 years       MORTGAGE     90000.0        Not Verified  Aug-2016
#
#         loan_status pymnt_plan  url desc             purpose  \
# 1758049  Fully Paid          n  NaN  NaN  debt_consolidation
# 686533      Current          n  NaN  NaN         credit_card
# 900721   Fully Paid          n  NaN  NaN      small_business
# 1727912  Fully Paid          n  NaN  NaN  debt_consolidation
# 539691      Current          n  NaN  NaN  debt_consolidation
#
#                            title zip_code addr_state    dti  delinq_2yrs  \
# 1758049           Hospital Debt     775xx         TX   3.51          0.0
# 686533   Credit card refinancing    782xx         TX  22.85          0.0
# 900721                  Business    210xx         MD   6.71          0.0
# 1727912       Debt Consolidation    282xx         NC  15.50          0.0
# 539691        Debt consolidation    658xx         MO  19.88          0.0
#
#         earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# 1758049         Nov-1997             0.0                    26.0
# 686533          Jun-2011             2.0                     NaN
# 900721          Apr-1996             0.0                     NaN
# 1727912         Aug-1998             0.0                     NaN
# 539691          Dec-2003             0.0                    41.0
#
#          mths_since_last_record  open_acc  pub_rec  revol_bal  revol_util  \
# 1758049                     NaN      14.0      0.0       1347         8.1
# 686533                      NaN      17.0      0.0      29780        52.7
# 900721                      NaN      16.0      0.0       7425        10.3
# 1727912                     NaN      10.0      0.0      24123        72.2
# 539691                      NaN      19.0      0.0      16615        49.9
#
#          total_acc initial_list_status  out_prncp  out_prncp_inv  \
# 1758049       22.0                   w       0.00           0.00
# 686533        25.0                   f   14987.66       14987.66
# 900721        25.0                   w       0.00           0.00
# 1727912       15.0                   f       0.00           0.00
# 539691        48.0                   w    2663.68        2663.68
#
#           total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  \
# 1758049  36606.090000         36606.09         35000.00        1606.09
# 686533   22115.610000         22115.61         15012.34        7103.27
# 900721   16052.052943         16052.05         15000.00        1052.05
# 1727912  39078.323239         39078.32         24000.00       15078.32
# 539691   13648.530000         13648.53         11736.32        1912.21
#
#          total_rec_late_fee  recoveries  collection_recovery_fee last_pymnt_d  \
# 1758049                 0.0         0.0                      0.0     Dec-2013
# 686533                  0.0         0.0                      0.0     Feb-2019
# 900721                  0.0         0.0                      0.0     Nov-2017
# 1727912                 0.0         0.0                      0.0     Sep-2018
# 539691                  0.0         0.0                      0.0     Feb-2019
#
#          last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 1758049          4783.54          NaN           Jan-2014
# 686533            648.54     Mar-2019           Feb-2019
# 900721          10466.17          NaN           Dec-2017
# 1727912           651.03          NaN           Feb-2019
# 539691            455.18     Mar-2019           Feb-2019
#
#          collections_12_mths_ex_med  mths_since_last_major_derog  policy_code  \
# 1758049                         0.0                         26.0            1
# 686533                          0.0                          NaN            1
# 900721                          0.0                          NaN            1
# 1727912                         0.0                          NaN            1
# 539691                          0.0                          NaN            1
#
#         application_type  annual_inc_joint  dti_joint  \
# 1758049       Individual               NaN        NaN
# 686533        Individual               NaN        NaN
# 900721        Individual               NaN        NaN
# 1727912       Individual               NaN        NaN
# 539691        Individual               NaN        NaN
#
#         verification_status_joint  acc_now_delinq  tot_coll_amt  tot_cur_bal  \
# 1758049                       NaN             0.0           0.0      81768.0
# 686533                        NaN             0.0           0.0      65689.0
# 900721                        NaN             0.0           0.0     150276.0
# 1727912                       NaN             0.0           0.0      27496.0
# 539691                        NaN             0.0           0.0     131564.0
#
#          open_acc_6m  open_act_il  open_il_12m  open_il_24m  \
# 1758049          NaN          NaN          NaN          NaN
# 686533           0.0          2.0          0.0          1.0
# 900721           0.0          1.0          0.0          0.0
# 1727912          NaN          NaN          NaN          NaN
# 539691           0.0          8.0          0.0          1.0
#
#          mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  open_rv_24m  \
# 1758049                 NaN           NaN      NaN          NaN          NaN
# 686533                 22.0       35909.0     64.0          0.0          3.0
# 900721                 30.0        9148.0     58.0          1.0          4.0
# 1727912                 NaN           NaN      NaN          NaN          NaN
# 539691                 19.0      114949.0    107.0          0.0          0.0
#
#          max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 1758049         NaN       NaN           16700.0     NaN          NaN
# 686533       7525.0      58.0           56500.0     4.0          9.0
# 900721       3673.0      19.0           72300.0     2.0          1.0
# 1727912         NaN       NaN           33400.0     NaN          NaN
# 539691       2745.0      93.0           33300.0     0.0          0.0
#
#          inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  \
# 1758049           NaN                   1.0       5841.0         12053.0
# 686533            5.0                   4.0       3864.0         12126.0
# 900721            1.0                   4.0       9392.0         45813.0
# 1727912           NaN                   2.0       2750.0          1447.0
# 539691            1.0                   1.0       7309.0         11121.0
#
#          bc_util  chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
#
aN             NaN            NaN              NaN
#
#         hardship_start_date hardship_end_date payment_plan_start_date  \
# 1758049                 NaN               NaN                     NaN
# 686533                  NaN               NaN                     NaN
# 900721                  NaN               NaN                     NaN
# 1727912                 NaN               NaN                     NaN
# 539691                  NaN               NaN                     NaN
#
#          hardship_length  hardship_dpd hardship_loan_status  \
# 1758049              NaN           NaN                  NaN
# 686533               NaN           NaN                  NaN
# 900721               NaN           NaN                  NaN
# 1727912              NaN           NaN                  NaN
# 539691               NaN           NaN                  NaN
#
#          orig_projected_additional_accrued_interest  \
# 1758049                                         NaN
# 686533                                          NaN
# 900721                                          NaN
# 1727912                                         NaN
# 539691                                          NaN
#
#          hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 1758049                             NaN                           NaN
# 686533                              NaN                           NaN
# 900721                              NaN                           NaN
# 1727912                             NaN                           NaN
# 539691                              NaN                           NaN
#
#         disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 1758049                Cash                    N                       NaN
# 686533                 Cash                    N                       NaN
# 900721                 Cash                    N                       NaN
# 1727912                Cash                    N                       NaN
# 539691                 Cash                    N                       NaN
#
#         settlement_status settlement_date  settlement_amount  \
# 1758049               NaN             NaN                NaN
# 686533                NaN             NaN                NaN
# 900721                NaN             NaN                NaN
# 1727912               NaN             NaN                NaN
# 539691                NaN             NaN                NaN
#
#          settlement_percentage  settlement_term
# 1758049                    NaN              NaN
# 686533                     NaN              NaN
# 900721                     NaN              NaN
# 1727912                    NaN              NaN
# 539691                     NaN              NaN

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2260668 entries, 0 to 2260667
# Columns: 145 entries, id to settlement_term
# dtypes: float64(105), int64(4), str(36)
# memory usage: 2.4 GB

# %%
df.dtypes
# Out:
# id                       float64
# member_id                float64
# loan_amnt                  int64
# funded_amnt                int64
# funded_amnt_inv          float64
#                           ...
# settlement_status            str
# settlement_date              str
# settlement_amount        float64
# settlement_percentage    float64
# settlement_term          float64
# Length: 145, dtype: object

# %%
df.dtypes.value_counts()
# Out:
# float64    105
# str         36
# int64        4
# Name: count, dtype: int64

# %%
df.describe().T
# Out:
#                                     count          mean          std     min  \
# id                                    0.0           NaN          NaN     NaN
# member_id                             0.0           NaN          NaN     NaN
# loan_amnt                       2260668.0  15046.931228  9190.245488  500.00
# funded_amnt                     2260668.0  15041.664057  9188.413022  500.00
# funded_amnt_inv                 2260668.0  15023.437624  9192.331807    0.00
# ...                                   ...           ...          ...     ...
# hardship_payoff_balance_amount    10613.0  11628.036442  7615.161123   55.73
# hardship_last_payment_amount      10613.0    193.606331   198.694368    0.01
# settlement_amount                 33056.0   5030.606922  3692.027842   44.21
# settlement_percentage             33056.0     47.775600     7.336379    0.20
# settlement_term                   33056.0     13.148596     8.192319    0.00
#
#                                     25%        50%         75%       max
# id                                  NaN        NaN         NaN       NaN
# member_id                           NaN        NaN         NaN       NaN
# loan_amnt                       8000.00  12900.000  20000.0000  40000.00
# funded_amnt                     8000.00  12875.000  20000.0000  40000.00
# funded_amnt_inv                 8000.00  12800.000  20000.0000  40000.00
# ...                                 ...        ...         ...       ...
# hardship_payoff_balance_amount  5628.73  10044.220  16114.9400  40306.41
# hardship_last_payment_amount      43.78    132.890    284.1800   1407.86
# settlement_amount               2227.00   4172.855   6870.7825  33601.00
# settlement_percentage             45.00     45.000     50.0000    521.35
# settlement_term                    6.00     14.000     18.0000    181.00
#
# [109 rows x 8 columns]

# %%
df.describe(include="object").T
# Out:
# C:\Users\henry\AppData\Local\Temp\ipykernel_6760\1274302342.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object").T
#                              count  unique                              top  \
# term                       2260668       2                        36 months
# grade                      2260668       7                                B
# sub_grade                  2260668      35                               C1
# emp_title                  2093699  512694                          Teacher
# emp_length                 2113761      11                        10+ years
# home_ownership             2260668       6                         MORTGAGE
# verification_status        2260668       3                  Source Verified
# issue_d                    2260668     139                         Mar-2016
# loan_status                2260668       9                       Fully Paid
# pymnt_plan                 2260668       2                                n
# desc                        126065  124500
# purpose                    2260668      14               debt_consolidation
# title                      2237342   63154               Debt consolidation
# zip_code                   2260667     956                            112xx
# addr_state                 2260668      51                               CA
# earliest_cr_line           2260639     754                         Sep-2004
# initial_list_status        2260668       2                                w
# last_pymnt_d               2258242     135                         Feb-2019
# next_pymnt_d                957061     105                         Mar-2019
# last_credit_pull_d         2260595     140                         Feb-2019
# application_type           2260668       2                       Individual
# verification_status_joint   115730       3                     Not Verified
# sec_app_earliest_cr_line    108021     663                         Aug-2006
# hardship_flag              2260668       2                                N
# hardship_type                10613       1  INTEREST ONLY-3 MONTHS DEFERRAL
# hardship_reason              10613       9                 NATURAL_DISASTER
# hardship_status              10613       3                        COMPLETED
# hardship_start_date          10613      26                         Sep-2017
# hardship_end_date            10613      27                         Dec-2017
# payment_plan_start_date      10613      26                         Sep-2017
# hardship_loan_status         10613       5                Late (16-30 days)
# disbursement_method        2260668       2                             Cash
# debt_settlement_flag       2260668       2                                N
# debt_settlement_flag_date    33056      82                         Feb-2019
# settlement_status            33056       3                           ACTIVE
# settlement_date              33056      89                         Jan-2019
#
#                               freq
# term                       1609754
# grade                       663557
# sub_grade                   145903
# emp_title                    38824
# emp_length                  748005
# home_ownership             1111450
# verification_status         886231
# issue_d                      61992
# loan_status                1041952
# pymnt_plan                 2259986
# desc                           252
# purpose                    1277877
# title                      1153293
# zip_code                     23908
# addr_state                  314533
# earliest_cr_line             15400
# initial_list_status        1535467
# last_pymnt_d                934725
# next_pymnt_d                953821
# last_credit_pull_d         1398266
# application_type           2139958
# verification_status_joint    57403
# sec_app_earliest_cr_line       998
# hardship_flag              2259783
# hardship_type                10613
# hardship_reason               2965
# hardship_status               7541
# hardship_start_date           2444
# hardship_end_date             1756
# payment_plan_start_date       1715
# hardship_loan_status          4622
# disbursement_method        2182546
# debt_settlement_flag       2227612
# debt_settlement_flag_date     2730
# settlement_status            14811
# settlement_date               1725

# %%
missing = df.isnull().sum()

missing = missing[missing>0]

missing.sort_values(ascending=False)
# Out:
# id                                            2260668
# member_id                                     2260668
# url                                           2260668
# orig_projected_additional_accrued_interest    2252242
# hardship_loan_status                          2250055
#                                                ...
# acc_now_delinq                                     29
# earliest_cr_line                                   29
# delinq_amnt                                        29
# annual_inc                                          4
# zip_code                                            1
# Length: 113, dtype: int64

# %%
missing_percent = (df.isnull().sum()/len(df))*100

missing_percent = missing_percent.sort_values(ascending=False)
    
missing_percent.head(30)
# Out:
# id                                            100.000000
# member_id                                     100.000000
# url                                           100.000000
# orig_projected_additional_accrued_interest     99.627278
# hardship_amount                                99.530537
# hardship_dpd                                   99.530537
# hardship_loan_status                           99.530537
# deferral_term                                  99.530537
# hardship_end_date                              99.530537
# hardship_status                                99.530537
# hardship_start_date                            99.530537
# hardship_reason                                99.530537
# hardship_type                                  99.530537
# hardship_payoff_balance_amount                 99.530537
# hardship_last_payment_amount                   99.530537
# hardship_length                                99.530537
# payment_plan_start_date                        99.530537
# debt_settlement_flag_date                      98.537777
# settlement_term                                98.537777
# settlement_amount                              98.537777
# settlement_date                                98.537777
# settlement_percentage                          98.537777
# settlement_status                              98.537777
# sec_app_mths_since_last_major_derog            98.410116
# sec_app_revol_util                             95.302981
# revol_bal_joint                                95.221766
# sec_app_earliest_cr_line                       95.221722
# sec_app_mort_acc                               95.221722
# sec_app_open_act_il                            95.221722
# sec_app_num_rev_accts                          95.221722
# dtype: float64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
import numpy as np

numeric_cols = df.select_dtypes(include=np.number).columns

print(numeric_cols)
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'int_rate', 'installment', 'annual_inc', 'url', 'dti',
#        ...
#        'deferral_term', 'hardship_amount', 'hardship_length', 'hardship_dpd',
#        'orig_projected_additional_accrued_interest',
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='str', length=109)

# %%
cat_cols = df.select_dtypes(include="object").columns

print(cat_cols)
# Out:
# Index(['term', 'grade', 'sub_grade', 'emp_title', 'emp_length',
#        'home_ownership', 'verification_status', 'issue_d', 'loan_status',
#        'pymnt_plan', 'desc', 'purpose', 'title', 'zip_code', 'addr_state',
#        'earliest_cr_line', 'initial_list_status', 'last_pymnt_d',
#        'next_pymnt_d', 'last_credit_pull_d', 'application_type',
#        'verification_status_joint', 'sec_app_earliest_cr_line',
#        'hardship_flag', 'hardship_type', 'hardship_reason', 'hardship_status',
#        'hardship_start_date', 'hardship_end_date', 'payment_plan_start_date',
#        'hardship_loan_status', 'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date'],
#       dtype='str')
# C:\Users\henry\AppData\Local\Temp\ipykernel_6760\1265589173.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(include="object").columns

# %%
for col in cat_cols:
    print(col)
    print(df[col].nunique())
    print("-"*50)
# Out:
# term
# 2
# --------------------------------------------------
# grade
# 7
# --------------------------------------------------
# sub_grade
# 35
# --------------------------------------------------
# emp_title
# 512694
# --------------------------------------------------
# emp_length
# 11
# --------------------------------------------------
# home_ownership
# 6
# --------------------------------------------------
# verification_status
# 3
# --------------------------------------------------
# issue_d
# 139
# --------------------------------------------------
# loan_status
# 9
# --------------------------------------------------
# pymnt_plan
# 2
# --------------------------------------------------
# desc
# 124500
# --------------------------------------------------
# purpose
# 14
# --------------------------------------------------
# title
# 63154
# --------------------------------------------------
# zip_code
# 956
# --------------------------------------------------
# addr_state
# 51
# --------------------------------------------------
# earliest_cr_line
# 754
# --------------------------------------------------
# initial_list_status
# 2
# --------------------------------------------------
# last_pymnt_d
# 135
# --------------------------------------------------
# next_pymnt_d
# 105
# --------------------------------------------------
# last_credit_pull_d
# 140
# --------------------------------------------------
# application_type
# 2
# --------------------------------------------------
# verification_status_joint
# 3
# --------------------------------------------------
# sec_app_earliest_cr_line
# 663
# --------------------------------------------------
# hardship_flag
# 2
# --------------------------------------------------
# hardship_type
# 1
# --------------------------------------------------
# hardship_reason
# 9
# --------------------------------------------------
# hardship_status
# 3
# --------------------------------------------------
# hardship_start_date
# 26
# --------------------------------------------------
# hardship_end_date
# 27
# --------------------------------------------------
# payment_plan_start_date
# 26
# --------------------------------------------------
# hardship_loan_status
# 5
# --------------------------------------------------
# disbursement_method
# 2
# --------------------------------------------------
# debt_settlement_flag
# 2
# --------------------------------------------------
# debt_settlement_flag_date
# 82
# --------------------------------------------------
# settlement_status
# 3
# --------------------------------------------------
# settlement_date
# 89
# --------------------------------------------------

# %%
df.memory_usage(deep=True).sum()/1024**2
# Out:
# np.float64(5554.151349067688)

# %%
important_cols = [
    "loan_amnt",
    "funded_amnt",
    "term",
    "int_rate",
    "grade",
    "sub_grade",
    "emp_length",
    "home_ownership",
    "annual_inc",
    "loan_status",
    "purpose",
]

# %%
df["loan_status"].value_counts()
# Out:
# loan_status
# Fully Paid                                             1041952
# Current                                                 919695
# Charged Off                                             261655
# Late (31-120 days)                                       21897
# In Grace Period                                           8952
# Late (16-30 days)                                         3737
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     31
# Name: count, dtype: int64
